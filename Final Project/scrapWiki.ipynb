# %% [markdown]
# ### Scraping the Tarkov wiki for information on tasks, hideout requirements, and trader information

# %% [markdown]
# General list of all the tasks

# %%
import requests
from bs4 import BeautifulSoup
import re
import time

task_URL = "https://escapefromtarkov.fandom.com/wiki/Quests"
task_page = requests.get(task_URL)
tasks = BeautifulSoup(task_page.content, "html.parser")
task_table = tasks.find_all("tr")

# %%
import pandas as pd
# pd.set_option("display.max_rows", 50)
pd.set_option("display.max_rows", None)

# %%
task_df = pd.DataFrame()
name_arr = [None] * len(task_table)
type_arr = [None] * len(task_table)
link_arr = [None] * len(task_table)
list_req_arr = [None] * len(task_table)
kappa_req_arr = [None] * len(task_table)

# Looking through all tasks on the main EFT wiki quests page
for x in range(len(task_table)):
    list_req = []
    # Get the name of the task
    try:
        name = task_table[x].find_all("th")[0].get_text().replace("\n","")
    except:
        temp = "nothing exists"
    
    name_arr[x] = name


    # Get the type of the task
    try:
        type = task_table[x].find_all("th")[1].get_text().replace("\n","")
    except:
        type = "none"
    
    type_arr[x] = type


    # Get the link for the task
    try:
        link = task_table[x].find("a", href=True)["href"]
    except:
        link = "none"
    
    link_arr[x] = link


    # Get task requirements
    # array of requirements
    try:
        list_req = [None] * len(task_table[x].find("td").find_all("li"))
        for y in range(len(task_table[x].find("td").find_all("li"))):
            list_req[y] = task_table[x].find("td").find_all("li")[y].get_text().replace("\n","") 
    except:
        list_req = []
    
    list_req_arr[x] = list_req


    # Find if task is required for Kappa
    try:
        last = len(task_table[x].find_all("th")) - 1
        kappa_req = task_table[x].find_all("th")[last].get_text().replace("\n","")
    except:
        kappa_req = "none"

    kappa_req_arr[x] = kappa_req


# Adding information to the task_df
task_df["Task Name"] = name_arr
task_df["Link to task"] = link_arr
task_df["Type"] = type_arr
task_df["Requirements"] = list_req_arr
task_df["Required for Kappa"] = kappa_req_arr

# This current scraps unnessary information, this removes that, more tasks added in the future will break this
task_df.drop(index=range(360,len(task_df)), axis=0, inplace=True)

# %%
main_wiki_link = "https://escapefromtarkov.fandom.com"
next_task_arr = [None] * len(task_df)
level_req_arr = [None] * len(task_df)

for i in range(len(task_df)):
    task = []
    temp_link = main_wiki_link + task_df.iloc[i]["Link to task"]
    individual_page = requests.get(temp_link)
    individual = BeautifulSoup(individual_page.content, "html.parser")
    if task_df.iloc[i]["Link to task"] != "none":
        info_boxes = individual.find_all("td", {"class" : "va-infobox-content"})
        index = None
        for j, td in enumerate(info_boxes):
            if "Leads to:" in td.get_text():
                index = j
                break
        try:
            leads = info_boxes[index].contents
            leads_list = [None] * len(leads)
            for w in range(1, len(leads)):
                if leads[w].get_text() != "":
                    leads_list[w] = leads[w].get_text()
            
            for lead in leads_list:
                if lead != None:
                    if lead != "-":
                        if "(" not in lead:
                            task.append(lead)
            
        except:
            task = []
    else:
        task = []
    next_task_arr[i] = task

    all_h2 = individual.find_all("h2")
    checker = all_h2[2].find(id="Requirements")
    level_req = None
    if checker != None:
        level_string = all_h2[2].find_next_sibling().get_text()
        level = re.findall(r'\d+', level_string)
        try:
            level_req = level[0]
        except:
            level_req = None

    level_req_arr[i] = level_req
    # print("Completed " + str(i + 1) + " out of " + str(len(task_df)) + ": " + str(temp_link))

task_df["Leads to:"] = next_task_arr
task_df["Level Requirement"] = level_req_arr

# %%
trader_arr = ["Prapor","Therapist","Skier","Peacekeeper","Mechanic","Ragman","Jaeger","Fence","Lightkeeper"]
trader_row_arr = [None] * len(trader_arr)

for trader in range(len(trader_arr)):
    trader_row_info = task_df[task_df["Link to task"].str.contains(trader_arr[trader])]
    trader_row_arr[trader] = trader_row_info.index[0]

# %%
trader_df = pd.DataFrame()
trader_link_arr = [None] * len(trader_row_arr)

for p in range(len(trader_row_arr)):
    trade = trader_row_arr[p]
    testing = task_df.at[trade, "Link to task"]
    trader_link_arr[p] = testing

trader_df["Trader Name"] = trader_arr
trader_df["Link to trader"] = trader_link_arr
trader_df
# Out:
#    Trader Name     Link to trader
# 0       Prapor       /wiki/Prapor
# 1    Therapist    /wiki/Therapist
# 2        Skier        /wiki/Skier
# 3  Peacekeeper  /wiki/Peacekeeper
# 4     Mechanic     /wiki/Mechanic
# 5       Ragman       /wiki/Ragman
# 6       Jaeger       /wiki/Jaeger
# 7        Fence        /wiki/Fence
# 8  Lightkeeper  /wiki/Lightkeeper

# %%
trader_labeling_arr = [None] * len(task_df)
find = 1

for r in range(len(task_df)):
    to_check = int(task_df.iloc[[r]].index[0])
    try:
        if to_check < trader_row_arr[find]:
            trader_labeling_arr[r] = trader_arr[find - 1]
        else:
            find += 1
            trader_labeling_arr[r] = trader_arr[find - 1]
    except:
        trader_labeling_arr[r] = trader_arr[find - 1]

task_df["Trader"] = trader_labeling_arr

# %%
remove_arr = [None] * len(trader_row_arr)

for t in range(len(trader_row_arr)):
    remove = trader_row_arr[t] + 1
    remove_arr[t] = remove

task_df.drop(index=remove_arr, axis=1, inplace=True)
task_df.drop(index=trader_row_arr, axis=1, inplace=True)
task_df = task_df.reset_index(drop=True)

# %%
comes_from_arr = [[] for _ in range(len(task_df))]
task_name_arr = task_df["Task Name"]

for u in range(len(task_df)):
    current_arr = task_df.iloc[u]["Leads to:"]
    for n in range(len(current_arr)):
        for v in range(len(task_df)):
            if current_arr[n] == task_df.iloc[v]["Task Name"]:
                comes_from_arr[v].append(u)
                break

task_df["Previous task"] = comes_from_arr

# %%
task_df.to_json("task.json", orient = "values", index = "true")
trader_df.to_json("trader.json", orient = "values", index = "true")

# %%
task_df
# Out:
#                                             Task Name  \
# 0                                       Shooting Cans
# 1                                               Debut
# 2                                      Luxurious Life
# 3                               Properties All Around
# 4                                      Search Mission
# 5                                    Background Check
# 6                                     Shootout Picnic
# 7                              Delivery From the Past
# 8                                            BP Depot
# 9                                 The Bunker - Part 1
# 10                                The Bunker - Part 2
# 11                                   Bad Rep Evidence
# 12                                    Ice Cream Cones
# 13                             No Place for Renegades
# 14                                          Documents
# 15                               Postman Pat - Part 1
# 16                              Shaking up the Teller
# 17                              The Punisher - Part 1
# 18                              The Punisher - Part 2
# 19                              The Punisher - Part 3
# 20                              The Punisher - Part 4
# 21                              The Punisher - Part 5
# 22                              The Punisher - Part 6
# 23                                         Anesthesia
# 24                                          Grenadier
# 25                                Test Drive - Part 1
# 26                                Test Drive - Part 2
# 27                                Test Drive - Part 3
# 28                                Test Drive - Part 4
# 29                                   Perfect Mediator
# 30                                      Polikhim Hobo
# 31                                Regulated Materials
# 32                                       Big Customer
# 33                                         No Offence
# 34                                 Capturing Outposts
# 35                                        Intimidator
# 36                                             Escort
# 37                                  Easy Job - Part 1
# 38                                  Easy Job - Part 2
# 39                                       Our Own Land
# 40                                     Reconnaissance
# 41                                    You've Got Mail
# 42                             Glory to CPSU - Part 1
# 43                             Glory to CPSU - Part 2
# 44                              Best Job in the World
# 45                              Kings of the Rooftops
# 46                                     Green Corridor
# 47                             Gendarmerie - Mall Cop
# 48                      Gendarmerie - Tickets, Please
# 49                      Gendarmerie - District Patrol
# 50                                      First in Line
# 51                                           Shortage
# 52                        Operation Aquarius - Part 1
# 53                        Operation Aquarius - Part 2
# 54                        Sanitary Standards - Part 1
# 55                        Sanitary Standards - Part 2
# 56                                         Painkiller
# 57                                         Pharmacist
# 58                                         Car Repair
# 59                                    Disease History
# 60                                       Supply Plans
# 61                       Health Care Privacy - Part 1
# 62                       Health Care Privacy - Part 2
# 63                       Health Care Privacy - Part 3
# 64               An Apple a Day Keeps the Doctor Away
# 65                       Health Care Privacy - Part 4
# 66                                            Athlete
# 67                                     Private Clinic
# 68                       Health Care Privacy - Part 5
# 69                            Decontamination Service
# 70                                      General Wares
# 71                                Colleagues - Part 1
# 72                                Colleagues - Part 2
# 73                                Colleagues - Part 3
# 74                               Postman Pat - Part 2
# 75                                   Out of Curiosity
# 76                                       Trust Regain
# 77                                             Crisis
# 78                                   Seaside Vacation
# 79                                       Lost Contact
# 80                                  Population Census
# 81                                     Dangerous Road
# 82                                     Urban Medicine
# 83                                   Drug Trafficking
# 84                        Pets Won't Need It - Part 1
# 85                        Pets Won't Need It - Part 2
# 86                                   Ambulances Again
# 87                                     Burning Rubber
# 88                                           Supplier
# 89                                   The Extortionist
# 90                                            Stirrup
# 91                         What’s on the Flash Drive?
# 92                                        Golden Swag
# 93                                  Chemical - Part 1
# 94                                  Chemical - Part 2
# 95                                  Chemical - Part 3
# 96                                  Chemical - Part 4
# 97                                     Loyalty Buyout
# 98                                  Vitamins - Part 1
# 99                                  Vitamins - Part 2
# 100                     Friend From the West - Part 1
# 101                     Friend From the West - Part 2
# 102                              Informed Means Armed
# 103                                          Chumming
# 104                                    Silent Caliber
# 105                                          Bullshit
# 106                                             Setup
# 107                                             Flint
# 108                               Lend-Lease - Part 1
# 109                                  Kind of Sabotage
# 110                                       Rigged Game
# 111                                     Safe Corridor
# 112                                       Night Sweep
# 113                                         Long Road
# 114                                     Missing Cargo
# 115                                        Top Secret
# 116                             House Arrest - Part 1
# 117                             House Arrest - Part 2
# 118                                            Debtor
# 119                      Beyond the Red Meat - Part 1
# 120                      Beyond the Red Meat - Part 2
# 121                                    Pyramid Scheme
# 122                                        No Swiping
# 123                                      Fishing Gear
# 124                                       Tigr Safari
# 125                                       Scrap Metal
# 126                                         Eagle Eye
# 127                             Humanitarian Supplies
# 128                                 The Cult - Part 1
# 129                                 The Cult - Part 2
# 130                                 Spa Tour - Part 1
# 131                                 Spa Tour - Part 2
# 132                                 Spa Tour - Part 3
# 133                                 Spa Tour - Part 4
# 134                                 Spa Tour - Part 5
# 135                                 Spa Tour - Part 6
# 136                                 Spa Tour - Part 7
# 137                                  Cargo X - Part 1
# 138                                  Cargo X - Part 2
# 139                                  Cargo X - Part 3
# 140                                  Wet Job - Part 1
# 141                                  Wet Job - Part 2
# 142                                  Wet Job - Part 3
# 143                                  Wet Job - Part 4
# 144                                  Wet Job - Part 5
# 145                                            Mentor
# 146                                  Wet Job - Part 6
# 147                                         The Guide
# 148                                           Samples
# 149                               TerraGroup Employee
# 150                               Lend-Lease - Part 2
# 151                              Peacekeeping Mission
# 152                           Classified Technologies
# 153                                Revision - Reserve
# 154                                       The Cleaner
# 155                                 Special Equipment
# 156                                  Cargo X - Part 4
# 157                                          Insomnia
# 158                                     Counteraction
# 159                                    Overpopulation
# 160                             Revision - Lighthouse
# 161                                          Trophies
# 162                      Revision - Streets of Tarkov
# 163                                       Road Closed
# 164                            Worst Job in the World
# 165                          Your Car Needs a Service
# 166                                   Saving the Mole
# 167                                      Introduction
# 168                                 Gunsmith - Part 1
# 169                                 Gunsmith - Part 2
# 170                                 Gunsmith - Part 3
# 171                                 Gunsmith - Part 4
# 172                                 Gunsmith - Part 5
# 173                                 Gunsmith - Part 6
# 174                                 Gunsmith - Part 7
# 175                                 Gunsmith - Part 8
# 176                                 Gunsmith - Part 9
# 177                                Gunsmith - Part 10
# 178                                Gunsmith - Part 11
# 179                                Gunsmith - Part 12
# 180                                Gunsmith - Part 13
# 181                                Gunsmith - Part 14
# 182                                Gunsmith - Part 15
# 183                                Gunsmith - Part 16
# 184                                Gunsmith - Part 17
# 185                                Gunsmith - Part 18
# 186                                Gunsmith - Part 19
# 187                                Gunsmith - Part 20
# 188                                Gunsmith - Part 21
# 189                                Gunsmith - Part 22
# 190                                Gunsmith - Part 23
# 191                                Gunsmith - Part 24
# 192                                Gunsmith - Part 25
# 193                                   Signal - Part 1
# 194                                           Insider
# 195                                   Signal - Part 2
# 196                                             Scout
# 197                                     Surplus Goods
# 198                                         Back Door
# 199                                   Signal - Part 3
# 200                                   Signal - Part 4
# 201                                  Farming - Part 1
# 202                                  Farming - Part 2
# 203                                         Bad Habit
# 204                                  Farming - Part 3
# 205                                  Farming - Part 4
# 206                                     Psycho Sniper
# 207                          A Shooter Born in Heaven
# 208                                       Fertilizers
# 209                                            Import
# 210                                  Chemistry Closet
# 211                                       Calibration
# 212                                       The Courier
# 213                                 Corporate Secrets
# 214                                     Energy Crisis
# 215                                Broadcast - Part 1
# 216                                Broadcast - Part 2
# 217                                      Surveillance
# 218                                      Watching You
# 219                         Network Provider - Part 1
# 220                         Network Provider - Part 2
# 221                               Assessment - Part 1
# 222                               Assessment - Part 2
# 223                               Assessment - Part 3
# 224                                  Key to the Tower
# 225                                       Knock-Knock
# 226                                Getting Acquainted
# 227                              Make Amends - Buyout
# 228                           Make Amends - Equipment
# 229                                       Make Amends
# 230                                          The Door
# 231                                     Steady Signal
# 232                      Developer's Secrets - Part 1
# 233                      Developer's Secrets - Part 2
# 234                                     Only Business
# 235                            Make ULTRA Great Again
# 236                                          Big Sale
# 237                                     A Fuel Matter
# 238                                   Inventory Check
# 239                         The Blood of War - Part 1
# 240                                   Dressed to Kill
# 241                                         Gratitude
# 242                                      Hot Delivery
# 243                                         Scavenger
# 244                                       Sales Night
# 245                                 Database - Part 1
# 246                                 Database - Part 2
# 247                                           Minibus
# 248                              Sew it Good - Part 1
# 249                         The Blood of War - Part 2
# 250                         The Blood of War - Part 3
# 251                              Sew it Good - Part 2
# 252                                The Key to Success
# 253                                    No Fuss Needed
# 254                                   The Stylish One
# 255                                        Supervisor
# 256                              Sew it Good - Part 3
# 257               Living High is Not a Crime - Part 1
# 258               Living High is Not a Crime - Part 2
# 259                              Sew it Good - Part 4
# 260                           Charisma Brings Success
# 261                                  Textile - Part 1
# 262                                  Textile - Part 2
# 263                                         Long Line
# 264                                             Booze
# 265                                             Audit
# 266                                      Ballet Lover
# 267                                        Audiophile
# 268                           Overseas Trust - Part 2
# 269                                           Dandies
# 270                          Nothing Fishy About This
# 271                                      Acquaintance
# 272  The Survivalist Path - Unprotected but Dangerous
# 273                    The Survivalist Path - Thrifty
# 274                   The Survivalist Path - Zhivchik
# 275              The Survivalist Path - Wounded Beast
# 276                  The Survivalist Path - Tough Guy
# 277                                    Courtesy Visit
# 278                                         Nostalgia
# 279               The Survivalist Path - Cold Blooded
# 280                     The Survivalist Path - Junkie
# 281                  The Survivalist Path - Eagle-Owl
# 282               The Survivalist Path - Combat Medic
# 283                                         Ambulance
# 284             The Huntsman Path - Secured Perimeter
# 285                   The Huntsman Path - Crooked Cop
# 286                                           Reserve
# 287               The Huntsman Path - Forest Cleaning
# 288                    The Huntsman Path - Controller
# 289                 The Huntsman Path - Evil Watchman
# 290                                     Fishing Place
# 291                        The Huntsman Path - Trophy
# 292                       The Huntsman Path - Justice
# 293                       The Huntsman Path - Sellout
# 294                  The Huntsman Path - Woods Keeper
# 295                                      Hunting Trip
# 296                 The Huntsman Path - Factory Chief
# 297               The Huntsman Path - Eraser - Part 1
# 298               The Huntsman Path - Eraser - Part 2
# 299                       The Tarkov Shooter - Part 1
# 300                       The Tarkov Shooter - Part 2
# 301                       The Tarkov Shooter - Part 3
# 302                       The Tarkov Shooter - Part 4
# 303                       The Tarkov Shooter - Part 5
# 304                       The Tarkov Shooter - Part 6
# 305                       The Tarkov Shooter - Part 7
# 306                       The Tarkov Shooter - Part 8
# 307                                    Shady Business
# 308                        The Huntsman Path - Sadist
# 309                                            Hunter
# 310                                      Pest Control
# 311                                         Swift One
# 312                    The Huntsman Path - Relentless
# 313                                        The Hermit
# 314                      The Huntsman Path - Outcasts
# 315                                        Stray Dogs
# 316                             The Delicious Sausage
# 317                                       Cease Fire!
# 318                                    Slaughterhouse
# 319                                Broadcast - Part 3
# 320                                Broadcast - Part 4
# 321                 The Huntsman Path - Administrator
# 322                      The Huntsman Path - Big Game
# 323                                Broadcast - Part 5
# 324                                         Collector
# 325                                        The Choice
# 326                   Compensation for Damage - Wager
# 327                   Compensation for Damage - Trust
# 328                 Compensation for Damage - Wergild
# 329                 Compensation for Damage - Barkeep
# 330              Compensation for Damage - Collection
# 331                                Information Source
# 332                                 Missing Informant
# 333                                            Snatch
# 334                                  Return the Favor
# 335                                           Payback
# 336                                       Provocation
# 337                        Following the Bread Crumbs
# 338                                           Spotter
# 339                                Make an Impression
# 340                           Trouble in the Big City
# 341                           Overseas Trust - Part 1
#
#                                           Link to task  \
# 0                                  /wiki/Shooting_Cans
# 1                                          /wiki/Debut
# 2                                 /wiki/Luxurious_Life
# 3                          /wiki/Properties_All_Around
# 4                                 /wiki/Search_Mission
# 5                               /wiki/Background_Check
# 6                                /wiki/Shootout_Picnic
# 7                         /wiki/Delivery_From_the_Past
# 8                                       /wiki/BP_Depot
# 9                            /wiki/The_Bunker_-_Part_1
# 10                           /wiki/The_Bunker_-_Part_2
# 11                              /wiki/Bad_Rep_Evidence
# 12                               /wiki/Ice_Cream_Cones
# 13                        /wiki/No_Place_for_Renegades
# 14                                     /wiki/Documents
# 15                          /wiki/Postman_Pat_-_Part_1
# 16                         /wiki/Shaking_up_the_Teller
# 17                         /wiki/The_Punisher_-_Part_1
# 18                         /wiki/The_Punisher_-_Part_2
# 19                         /wiki/The_Punisher_-_Part_3
# 20                         /wiki/The_Punisher_-_Part_4
# 21                         /wiki/The_Punisher_-_Part_5
# 22                         /wiki/The_Punisher_-_Part_6
# 23                                    /wiki/Anesthesia
# 24                                     /wiki/Grenadier
# 25                           /wiki/Test_Drive_-_Part_1
# 26                           /wiki/Test_Drive_-_Part_2
# 27                           /wiki/Test_Drive_-_Part_3
# 28                           /wiki/Test_Drive_-_Part_4
# 29                              /wiki/Perfect_Mediator
# 30                                 /wiki/Polikhim_Hobo
# 31                           /wiki/Regulated_Materials
# 32                                  /wiki/Big_Customer
# 33                                    /wiki/No_Offence
# 34                            /wiki/Capturing_Outposts
# 35                                   /wiki/Intimidator
# 36                                        /wiki/Escort
# 37                             /wiki/Easy_Job_-_Part_1
# 38                             /wiki/Easy_Job_-_Part_2
# 39                                  /wiki/Our_Own_Land
# 40                                /wiki/Reconnaissance
# 41                             /wiki/You%27ve_Got_Mail
# 42                        /wiki/Glory_to_CPSU_-_Part_1
# 43                        /wiki/Glory_to_CPSU_-_Part_2
# 44                         /wiki/Best_Job_in_the_World
# 45                         /wiki/Kings_of_the_Rooftops
# 46                                /wiki/Green_Corridor
# 47                        /wiki/Gendarmerie_-_Mall_Cop
# 48                 /wiki/Gendarmerie_-_Tickets,_Please
# 49                 /wiki/Gendarmerie_-_District_Patrol
# 50                                 /wiki/First_in_Line
# 51                                      /wiki/Shortage
# 52                   /wiki/Operation_Aquarius_-_Part_1
# 53                   /wiki/Operation_Aquarius_-_Part_2
# 54                   /wiki/Sanitary_Standards_-_Part_1
# 55                   /wiki/Sanitary_Standards_-_Part_2
# 56                                    /wiki/Painkiller
# 57                                    /wiki/Pharmacist
# 58                                    /wiki/Car_Repair
# 59                               /wiki/Disease_History
# 60                                  /wiki/Supply_Plans
# 61                  /wiki/Health_Care_Privacy_-_Part_1
# 62                  /wiki/Health_Care_Privacy_-_Part_2
# 63                  /wiki/Health_Care_Privacy_-_Part_3
# 64          /wiki/An_Apple_a_Day_Keeps_the_Doctor_Away
# 65                  /wiki/Health_Care_Privacy_-_Part_4
# 66                                       /wiki/Athlete
# 67                                /wiki/Private_Clinic
# 68                  /wiki/Health_Care_Privacy_-_Part_5
# 69                       /wiki/Decontamination_Service
# 70                                 /wiki/General_Wares
# 71                           /wiki/Colleagues_-_Part_1
# 72                           /wiki/Colleagues_-_Part_2
# 73                           /wiki/Colleagues_-_Part_3
# 74                          /wiki/Postman_Pat_-_Part_2
# 75                              /wiki/Out_of_Curiosity
# 76                                  /wiki/Trust_Regain
# 77                                        /wiki/Crisis
# 78                              /wiki/Seaside_Vacation
# 79                                  /wiki/Lost_Contact
# 80                             /wiki/Population_Census
# 81                                /wiki/Dangerous_Road
# 82                                /wiki/Urban_Medicine
# 83                              /wiki/Drug_Trafficking
# 84                 /wiki/Pets_Won%27t_Need_It_-_Part_1
# 85                 /wiki/Pets_Won%27t_Need_It_-_Part_2
# 86                              /wiki/Ambulances_Again
# 87                                /wiki/Burning_Rubber
# 88                                      /wiki/Supplier
# 89                              /wiki/The_Extortionist
# 90                                       /wiki/Stirrup
# 91          /wiki/What%E2%80%99s_on_the_Flash_Drive%3F
# 92                                   /wiki/Golden_Swag
# 93                             /wiki/Chemical_-_Part_1
# 94                             /wiki/Chemical_-_Part_2
# 95                             /wiki/Chemical_-_Part_3
# 96                             /wiki/Chemical_-_Part_4
# 97                                /wiki/Loyalty_Buyout
# 98                             /wiki/Vitamins_-_Part_1
# 99                             /wiki/Vitamins_-_Part_2
# 100                /wiki/Friend_From_the_West_-_Part_1
# 101                /wiki/Friend_From_the_West_-_Part_2
# 102                         /wiki/Informed_Means_Armed
# 103                                     /wiki/Chumming
# 104                               /wiki/Silent_Caliber
# 105                                     /wiki/Bullshit
# 106                                        /wiki/Setup
# 107                                        /wiki/Flint
# 108                          /wiki/Lend-Lease_-_Part_1
# 109                             /wiki/Kind_of_Sabotage
# 110                                  /wiki/Rigged_Game
# 111                                /wiki/Safe_Corridor
# 112                                  /wiki/Night_Sweep
# 113                                    /wiki/Long_Road
# 114                                /wiki/Missing_Cargo
# 115                                   /wiki/Top_Secret
# 116                        /wiki/House_Arrest_-_Part_1
# 117                        /wiki/House_Arrest_-_Part_2
# 118                                       /wiki/Debtor
# 119                 /wiki/Beyond_the_Red_Meat_-_Part_1
# 120                 /wiki/Beyond_the_Red_Meat_-_Part_2
# 121                               /wiki/Pyramid_Scheme
# 122                                   /wiki/No_Swiping
# 123                                 /wiki/Fishing_Gear
# 124                                  /wiki/Tigr_Safari
# 125                                  /wiki/Scrap_Metal
# 126                                    /wiki/Eagle_Eye
# 127                        /wiki/Humanitarian_Supplies
# 128                            /wiki/The_Cult_-_Part_1
# 129                            /wiki/The_Cult_-_Part_2
# 130                            /wiki/Spa_Tour_-_Part_1
# 131                            /wiki/Spa_Tour_-_Part_2
# 132                            /wiki/Spa_Tour_-_Part_3
# 133                            /wiki/Spa_Tour_-_Part_4
# 134                            /wiki/Spa_Tour_-_Part_5
# 135                            /wiki/Spa_Tour_-_Part_6
# 136                            /wiki/Spa_Tour_-_Part_7
# 137                             /wiki/Cargo_X_-_Part_1
# 138                             /wiki/Cargo_X_-_Part_2
# 139                             /wiki/Cargo_X_-_Part_3
# 140                             /wiki/Wet_Job_-_Part_1
# 141                             /wiki/Wet_Job_-_Part_2
# 142                             /wiki/Wet_Job_-_Part_3
# 143                             /wiki/Wet_Job_-_Part_4
# 144                             /wiki/Wet_Job_-_Part_5
# 145                                       /wiki/Mentor
# 146                             /wiki/Wet_Job_-_Part_6
# 147                                    /wiki/The_Guide
# 148                                      /wiki/Samples
# 149                          /wiki/TerraGroup_Employee
# 150                          /wiki/Lend-Lease_-_Part_2
# 151                         /wiki/Peacekeeping_Mission
# 152                      /wiki/Classified_Technologies
# 153                           /wiki/Revision_-_Reserve
# 154                                  /wiki/The_Cleaner
# 155                            /wiki/Special_Equipment
# 156                             /wiki/Cargo_X_-_Part_4
# 157                                     /wiki/Insomnia
# 158                                /wiki/Counteraction
# 159                               /wiki/Overpopulation
# 160                        /wiki/Revision_-_Lighthouse
# 161                                     /wiki/Trophies
# 162                 /wiki/Revision_-_Streets_of_Tarkov
# 163                                  /wiki/Road_Closed
# 164                       /wiki/Worst_Job_in_the_World
# 165                     /wiki/Your_Car_Needs_a_Service
# 166                              /wiki/Saving_the_Mole
# 167                                 /wiki/Introduction
# 168                            /wiki/Gunsmith_-_Part_1
# 169                            /wiki/Gunsmith_-_Part_2
# 170                            /wiki/Gunsmith_-_Part_3
# 171                            /wiki/Gunsmith_-_Part_4
# 172                            /wiki/Gunsmith_-_Part_5
# 173                            /wiki/Gunsmith_-_Part_6
# 174                            /wiki/Gunsmith_-_Part_7
# 175                            /wiki/Gunsmith_-_Part_8
# 176                            /wiki/Gunsmith_-_Part_9
# 177                           /wiki/Gunsmith_-_Part_10
# 178                           /wiki/Gunsmith_-_Part_11
# 179                           /wiki/Gunsmith_-_Part_12
# 180                           /wiki/Gunsmith_-_Part_13
# 181                           /wiki/Gunsmith_-_Part_14
# 182                           /wiki/Gunsmith_-_Part_15
# 183                           /wiki/Gunsmith_-_Part_16
# 184                           /wiki/Gunsmith_-_Part_17
# 185                           /wiki/Gunsmith_-_Part_18
# 186                           /wiki/Gunsmith_-_Part_19
# 187                           /wiki/Gunsmith_-_Part_20
# 188                           /wiki/Gunsmith_-_Part_21
# 189                           /wiki/Gunsmith_-_Part_22
# 190                           /wiki/Gunsmith_-_Part_23
# 191                           /wiki/Gunsmith_-_Part_24
# 192                           /wiki/Gunsmith_-_Part_25
# 193                              /wiki/Signal_-_Part_1
# 194                                      /wiki/Insider
# 195                              /wiki/Signal_-_Part_2
# 196                                        /wiki/Scout
# 197                                /wiki/Surplus_Goods
# 198                                    /wiki/Back_Door
# 199                              /wiki/Signal_-_Part_3
# 200                              /wiki/Signal_-_Part_4
# 201                             /wiki/Farming_-_Part_1
# 202                             /wiki/Farming_-_Part_2
# 203                                    /wiki/Bad_Habit
# 204                             /wiki/Farming_-_Part_3
# 205                             /wiki/Farming_-_Part_4
# 206                                /wiki/Psycho_Sniper
# 207                     /wiki/A_Shooter_Born_in_Heaven
# 208                                  /wiki/Fertilizers
# 209                                       /wiki/Import
# 210                             /wiki/Chemistry_Closet
# 211                                  /wiki/Calibration
# 212                                  /wiki/The_Courier
# 213                            /wiki/Corporate_Secrets
# 214                                /wiki/Energy_Crisis
# 215                           /wiki/Broadcast_-_Part_1
# 216                           /wiki/Broadcast_-_Part_2
# 217                                 /wiki/Surveillance
# 218                                 /wiki/Watching_You
# 219                    /wiki/Network_Provider_-_Part_1
# 220                    /wiki/Network_Provider_-_Part_2
# 221                          /wiki/Assessment_-_Part_1
# 222                          /wiki/Assessment_-_Part_2
# 223                          /wiki/Assessment_-_Part_3
# 224                             /wiki/Key_to_the_Tower
# 225                                  /wiki/Knock-Knock
# 226                           /wiki/Getting_Acquainted
# 227                         /wiki/Make_Amends_-_Buyout
# 228                      /wiki/Make_Amends_-_Equipment
# 229                                  /wiki/Make_Amends
# 230                                     /wiki/The_Door
# 231                                /wiki/Steady_Signal
# 232               /wiki/Developer%27s_Secrets_-_Part_1
# 233               /wiki/Developer%27s_Secrets_-_Part_2
# 234                                /wiki/Only_Business
# 235                       /wiki/Make_ULTRA_Great_Again
# 236                                     /wiki/Big_Sale
# 237                                /wiki/A_Fuel_Matter
# 238                              /wiki/Inventory_Check
# 239                    /wiki/The_Blood_of_War_-_Part_1
# 240                              /wiki/Dressed_to_Kill
# 241                                    /wiki/Gratitude
# 242                                 /wiki/Hot_Delivery
# 243                                    /wiki/Scavenger
# 244                                  /wiki/Sales_Night
# 245                            /wiki/Database_-_Part_1
# 246                            /wiki/Database_-_Part_2
# 247                                      /wiki/Minibus
# 248                         /wiki/Sew_it_Good_-_Part_1
# 249                    /wiki/The_Blood_of_War_-_Part_2
# 250                    /wiki/The_Blood_of_War_-_Part_3
# 251                         /wiki/Sew_it_Good_-_Part_2
# 252                           /wiki/The_Key_to_Success
# 253                               /wiki/No_Fuss_Needed
# 254                              /wiki/The_Stylish_One
# 255                                   /wiki/Supervisor
# 256                         /wiki/Sew_it_Good_-_Part_3
# 257          /wiki/Living_High_is_Not_a_Crime_-_Part_1
# 258          /wiki/Living_High_is_Not_a_Crime_-_Part_2
# 259                         /wiki/Sew_it_Good_-_Part_4
# 260                      /wiki/Charisma_Brings_Success
# 261                             /wiki/Textile_-_Part_1
# 262                             /wiki/Textile_-_Part_2
# 263                                    /wiki/Long_Line
# 264                                        /wiki/Booze
# 265                                        /wiki/Audit
# 266                                 /wiki/Ballet_Lover
# 267                                   /wiki/Audiophile
# 268                      /wiki/Overseas_Trust_-_Part_2
# 269                                      /wiki/Dandies
# 270                     /wiki/Nothing_Fishy_About_This
# 271                                 /wiki/Acquaintance
# 272  /wiki/The_Survivalist_Path_-_Unprotected_but_D...
# 273               /wiki/The_Survivalist_Path_-_Thrifty
# 274              /wiki/The_Survivalist_Path_-_Zhivchik
# 275         /wiki/The_Survivalist_Path_-_Wounded_Beast
# 276             /wiki/The_Survivalist_Path_-_Tough_Guy
# 277                               /wiki/Courtesy_Visit
# 278                                    /wiki/Nostalgia
# 279          /wiki/The_Survivalist_Path_-_Cold_Blooded
# 280                /wiki/The_Survivalist_Path_-_Junkie
# 281             /wiki/The_Survivalist_Path_-_Eagle-Owl
# 282          /wiki/The_Survivalist_Path_-_Combat_Medic
# 283                                    /wiki/Ambulance
# 284        /wiki/The_Huntsman_Path_-_Secured_Perimeter
# 285              /wiki/The_Huntsman_Path_-_Crooked_Cop
# 286                              /wiki/Reserve_(quest)
# 287          /wiki/The_Huntsman_Path_-_Forest_Cleaning
# 288               /wiki/The_Huntsman_Path_-_Controller
# 289            /wiki/The_Huntsman_Path_-_Evil_Watchman
# 290                                /wiki/Fishing_Place
# 291                   /wiki/The_Huntsman_Path_-_Trophy
# 292                  /wiki/The_Huntsman_Path_-_Justice
# 293                  /wiki/The_Huntsman_Path_-_Sellout
# 294             /wiki/The_Huntsman_Path_-_Woods_Keeper
# 295                                 /wiki/Hunting_Trip
# 296            /wiki/The_Huntsman_Path_-_Factory_Chief
# 297          /wiki/The_Huntsman_Path_-_Eraser_-_Part_1
# 298          /wiki/The_Huntsman_Path_-_Eraser_-_Part_2
# 299                  /wiki/The_Tarkov_Shooter_-_Part_1
# 300                  /wiki/The_Tarkov_Shooter_-_Part_2
# 301                  /wiki/The_Tarkov_Shooter_-_Part_3
# 302                  /wiki/The_Tarkov_Shooter_-_Part_4
# 303                  /wiki/The_Tarkov_Shooter_-_Part_5
# 304                  /wiki/The_Tarkov_Shooter_-_Part_6
# 305                  /wiki/The_Tarkov_Shooter_-_Part_7
# 306                  /wiki/The_Tarkov_Shooter_-_Part_8
# 307                               /wiki/Shady_Business
# 308                   /wiki/The_Huntsman_Path_-_Sadist
# 309                                       /wiki/Hunter
# 310                                 /wiki/Pest_Control
# 311                                    /wiki/Swift_One
# 312               /wiki/The_Huntsman_Path_-_Relentless
# 313                                   /wiki/The_Hermit
# 314                 /wiki/The_Huntsman_Path_-_Outcasts
# 315                                   /wiki/Stray_Dogs
# 316                        /wiki/The_Delicious_Sausage
# 317                                  /wiki/Cease_Fire!
# 318                               /wiki/Slaughterhouse
# 319                           /wiki/Broadcast_-_Part_3
# 320                           /wiki/Broadcast_-_Part_4
# 321            /wiki/The_Huntsman_Path_-_Administrator
# 322                 /wiki/The_Huntsman_Path_-_Big_Game
# 323                           /wiki/Broadcast_-_Part_5
# 324                                    /wiki/Collector
# 325                                   /wiki/The_Choice
# 326              /wiki/Compensation_for_Damage_-_Wager
# 327              /wiki/Compensation_for_Damage_-_Trust
# 328            /wiki/Compensation_for_Damage_-_Wergild
# 329            /wiki/Compensation_for_Damage_-_Barkeep
# 330         /wiki/Compensation_for_Damage_-_Collection
# 331                           /wiki/Information_Source
# 332                            /wiki/Missing_Informant
# 333                                       /wiki/Snatch
# 334                             /wiki/Return_the_Favor
# 335                                      /wiki/Payback
# 336                                  /wiki/Provocation
# 337                   /wiki/Following_the_Bread_Crumbs
# 338                                      /wiki/Spotter
# 339                           /wiki/Make_an_Impression
# 340                      /wiki/Trouble_in_the_Big_City
# 341                      /wiki/Overseas_Trust_-_Part_1
#
#                            Type  \
# 0                    Completion
# 1                   Elimination
# 2                        PickUp
# 3                        PickUp
# 4                   Exploration
# 5                        PickUp
# 6                   Elimination
# 7                        PickUp
# 8                     Discovery
# 9                    Completion
# 10                   Completion
# 11                       PickUp
# 12                       PickUp
# 13                  Elimination
# 14                       PickUp
# 15                       PickUp
# 16                       PickUp
# 17                  Elimination
# 18                  Elimination
# 19                  Elimination
# 20                  Elimination
# 21                       PickUp
# 22                  Elimination
# 23                    Discovery
# 24                  Elimination
# 25                  Elimination
# 26                  Elimination
# 27                  Elimination
# 28                  Elimination
# 29                     Standing
# 30                  Elimination
# 31                       PickUp
# 32                   Completion
# 33                       PickUp
# 34                  Elimination
# 35                  Elimination
# 36                  Elimination
# 37                    Discovery
# 38                  Elimination
# 39                  Elimination
# 40                  Exploration
# 41                   Completion
# 42                   Completion
# 43                       PickUp
# 44                  Elimination
# 45                  Elimination
# 46                  Exploration
# 47                  Elimination
# 48                  Elimination
# 49                  Elimination
# 50                  Exploration
# 51                       PickUp
# 52                       PickUp
# 53                  Elimination
# 54                       PickUp
# 55                   Completion
# 56                       PickUp
# 57                       PickUp
# 58                       PickUp
# 59                       PickUp
# 60                       PickUp
# 61                    Discovery
# 62                    Discovery
# 63                    Discovery
# 64                   Completion
# 65                        Skill
# 66                        Skill
# 67                   Completion
# 68                        Multi
# 69                  Elimination
# 70                   Completion
# 71                  Exploration
# 72                       PickUp
# 73                       PickUp
# 74                       PickUp
# 75                       PickUp
# 76                       PickUp
# 77                       PickUp
# 78                       PickUp
# 79                    Discovery
# 80                       PickUp
# 81                  Exploration
# 82                       PickUp
# 83                   Completion
# 84                  Exploration
# 85                  Exploration
# 86                       Pickup
# 87                   Completion
# 88                       PickUp
# 89                       PickUp
# 90                  Elimination
# 91                       PickUp
# 92                   Completion
# 93                       PickUp
# 94                       PickUp
# 95                       PickUp
# 96                       PickUp
# 97                     Standing
# 98                       PickUp
# 99                       PickUp
# 100                 Elimination
# 101                    Merchant
# 102                  Completion
# 103                  Completion
# 104                 Elimination
# 105                   Discovery
# 106                 Elimination
# 107                       Skill
# 108                      PickUp
# 109                      PickUp
# 110                   Discovery
# 111                 Elimination
# 112                      Pickup
# 113                 Elimination
# 114                 Exploration
# 115                      PickUp
# 116                 Exploration
# 117                 Exploration
# 118                 Exploration
# 119                      Pickup
# 120                      Pickup
# 121                 Exploration
# 122                 Elimination
# 123                  Completion
# 124                   Discovery
# 125                   Discovery
# 126                      PickUp
# 127                   Discovery
# 128                 Exploration
# 129                 Exploration
# 130                 Elimination
# 131                 Exploration
# 132                      PickUp
# 133                   Discovery
# 134                      PickUp
# 135                    Standing
# 136                      PickUp
# 137                      PickUp
# 138                 Exploration
# 139                       Multi
# 140                 Elimination
# 141                 Exploration
# 142                 Exploration
# 143                      PickUp
# 144                      PickUp
# 145                  Completion
# 146                       Skill
# 147                 Exploration
# 148                      PickUp
# 149                      PickUp
# 150                      PickUp
# 151                 Elimination
# 152                      Pickup
# 153                   Discovery
# 154                 Elimination
# 155                      PickUp
# 156                   Discovery
# 157                 Elimination
# 158                 Elimination
# 159                 Elimination
# 160                   Discovery
# 161                      Pickup
# 162                   Discovery
# 163                 Exploration
# 164                 Elimination
# 165                      PickUp
# 166                      PickUp
# 167                  Completion
# 168  Parameter-oriented modding
# 169  Parameter-oriented modding
# 170  Parameter-oriented modding
# 171  Parameter-oriented modding
# 172  Parameter-oriented modding
# 173  Parameter-oriented modding
# 174  Parameter-oriented modding
# 175  Parameter-oriented modding
# 176  Parameter-oriented modding
# 177  Parameter-oriented modding
# 178  Parameter-oriented modding
# 179  Parameter-oriented modding
# 180  Parameter-oriented modding
# 181  Parameter-oriented modding
# 182  Parameter-oriented modding
# 183  Parameter-oriented modding
# 184  Parameter-oriented modding
# 185  Parameter-oriented modding
# 186  Parameter-oriented modding
# 187  Parameter-oriented modding
# 188  Parameter-oriented modding
# 189  Parameter-oriented modding
# 190  Parameter-oriented modding
# 191  Parameter-oriented modding
# 192  Parameter-oriented modding
# 193                   Discovery
# 194                    Standing
# 195                      PickUp
# 196                  Completion
# 197                      Pickup
# 198                    Discover
# 199                  Completion
# 200                       Skill
# 201                  Completion
# 202                      PickUp
# 203                      PickUp
# 204                  Completion
# 205                      PickUp
# 206                       Skill
# 207                 Elimination
# 208                      PickUp
# 209                      PickUp
# 210                  Completion
# 211                 Elimination
# 212                  Completion
# 213                 Exploration
# 214                 Exploration
# 215                  Completion
# 216                  Completion
# 217                      PickUp
# 218                      PickUp
# 219                      PickUp
# 220                   Discovery
# 221                 Elimination
# 222                   Discovery
# 223        PickUp / Elimination
# 224                      PickUp
# 225                  Completion
# 226                      PickUp
# 227                     Loyalty
# 228                      PickUp
# 229                      PickUp
# 230                  Completion
# 231                  Completion
# 232                 Exploration
# 233                 Exploration
# 234                    Merchant
# 235                  Completion
# 236                 Exploration
# 237                  Completion
# 238                  Completion
# 239                  Completion
# 240                  Completion
# 241                  Completion
# 242                  Completion
# ...
# 294                 [Hunting Trip, Stray Dogs, Hunter]              None
# 295                                                 []                33
# 296                                                 []              None
# 297              [The Huntsman Path - Eraser - Part 2]              None
# 298                                                 []              None
# 299                      [The Tarkov Shooter - Part 2]              None
# 300                      [The Tarkov Shooter - Part 3]              None
# 301  [The Tarkov Shooter - Part 4, The Huntsman Pat...              None
# 302                      [The Tarkov Shooter - Part 5]              None
# 303                      [The Tarkov Shooter - Part 6]              None
# 304                      [The Tarkov Shooter - Part 7]              None
# 305                      [The Tarkov Shooter - Part 8]              None
# 306                                                 []              None
# 307                                        [Ambulance]                20
# 308                   [TerraGroup Employee, Swift One]              None
# 309                                                 []                 4
# 310              [The Huntsman Path - Eraser - Part 1]                10
# 311                                                 []                50
# 312                                                 []                65
# 313                                                 []                20
# 314                                                 []              None
# 315                                                 []                35
# 316                                      [Cease Fire!]                 5
# 317                                 [Ambulances Again]                10
# 318                                                 []                40
# 319                               [Broadcast - Part 4]                20
# 320               [Broadcast - Part 5, Slaughterhouse]                27
# 321  [The Huntsman Path - Crooked Cop, Slaughterhouse]                23
# 322                                                 []              None
# 323                                                 []              None
# 324                                                 []                48
# 325                                                 []                50
# 326                                                 []                 1
# 327                                                 []                 1
# 328                                                 []                 1
# 329                                                 []                 1
# 330                                                 []                 1
# 331                                [Missing Informant]              None
# 332                                           [Snatch]                10
# 333                                 [Return the Favor]                10
# 334                                          [Payback]                10
# 335                                      [Provocation]                10
# 336                       [Following the Bread Crumbs]                10
# 337                                          [Spotter]                10
# 338                               [Make an Impression]                10
# 339                          [Trouble in the Big City]                10
# 340                          [Overseas Trust - Part 1]                10
# 341                          [Overseas Trust - Part 2]                10
#
#           Trader    Previous task
# 0         Prapor               []
# 1         Prapor              [0]
# 2         Prapor              [1]
# 3         Prapor             [43]
# 4         Prapor              [1]
# 5         Prapor              [2]
# 6         Prapor              [5]
# 7         Prapor              [5]
# 8         Prapor              [7]
# 9         Prapor              [8]
# 10        Prapor              [9]
# 11        Prapor              [8]
# 12        Prapor             [11]
# 13        Prapor             [10]
# 14        Prapor             [13]
# 15        Prapor             [12]
# 16        Prapor             [12]
# 17        Prapor             [16]
# 18        Prapor             [17]
# 19        Prapor             [18]
# 20        Prapor             [19]
# 21        Prapor             [20]
# 22        Prapor             [21]
# 23        Prapor             [16]
# 24        Prapor               []
# 25        Prapor             [24]
# 26        Prapor             [25]
# 27        Prapor             [26]
# 28        Prapor             [27]
# 29        Prapor             [16]
# 30        Prapor             [93]
# 31        Prapor             [30]
# 32        Prapor             [95]
# 33        Prapor         [75, 96]
# 34        Prapor             [22]
# 35        Prapor             [22]
# 36        Prapor             [22]
# 37        Prapor             [18]
# 38        Prapor             [37]
# 39        Prapor             [21]
# 40        Prapor             [37]
# 41        Prapor             [15]
# 42        Prapor             [41]
# 43        Prapor             [42]
# 44        Prapor             [45]
# 45        Prapor             [20]
# 46        Prapor            [136]
# 47        Prapor             [22]
# 48        Prapor             [47]
# 49        Prapor             [48]
# 50     Therapist               []
# 51     Therapist             [50]
# 52     Therapist             [51]
# 53     Therapist             [52]
# 54     Therapist             [51]
# 55     Therapist             [54]
# 56     Therapist             [55]
# 57     Therapist             [56]
# 58     Therapist             [57]
# 59     Therapist             [57]
# 60     Therapist             [57]
# 61     Therapist             [57]
# 62     Therapist             [61]
# 63     Therapist             [62]
# 64     Therapist             [65]
# 65     Therapist             [63]
# 66     Therapist             [65]
# 67     Therapist             [65]
# 68     Therapist             [65]
# 69     Therapist         [67, 68]
# 70     Therapist             [57]
# 71     Therapist             [70]
# 72     Therapist             [71]
# 73     Therapist   [72, 110, 210]
# 74     Therapist             [15]
# 75     Therapist             [95]
# 76     Therapist         [32, 96]
# 77     Therapist               []
# 78     Therapist             [59]
# 79     Therapist             [62]
# 80     Therapist             [57]
# 81     Therapist        [60, 109]
# 82     Therapist             [80]
# 83     Therapist             [79]
# 84     Therapist             [80]
# 85     Therapist             [84]
# 86     Therapist        [82, 317]
# 87         Skier               []
# 88         Skier             [87]
# 89         Skier             [88]
# 90         Skier             [88]
# 91         Skier             [89]
# 92         Skier             [91]
# 93         Skier             [92]
# 94         Skier             [93]
# 95         Skier             [94]
# 96         Skier             [95]
# 97         Skier         [32, 75]
# 98         Skier             [95]
# 99         Skier             [98]
# 100        Skier             [88]
# 101        Skier            [100]
# 102        Skier            [106]
# 103        Skier            [102]
# 104        Skier            [105]
# 105        Skier            [103]
# 106        Skier            [101]
# 107        Skier            [103]
# 108        Skier            [101]
# 109        Skier             [57]
# 110        Skier             [23]
# 111        Skier     [32, 75, 96]
# 112        Skier            [110]
# 113        Skier            [101]
# 114        Skier            [113]
# 115        Skier       [114, 226]
# 116        Skier            [118]
# 117        Skier            [116]
# 118        Skier            [103]
# 119        Skier             [99]
# 120        Skier            [119]
# 121        Skier             [99]
# 122        Skier            [103]
# 123  Peacekeeper            [101]
# 124  Peacekeeper            [123]
# 125  Peacekeeper            [124]
# 126  Peacekeeper            [125]
# 127  Peacekeeper            [126]
# 128  Peacekeeper            [127]
# 129  Peacekeeper            [128]
# 130  Peacekeeper            [127]
# 131  Peacekeeper            [130]
# 132  Peacekeeper            [131]
# 133  Peacekeeper            [132]
# 134  Peacekeeper            [133]
# 135  Peacekeeper            [134]
# 136  Peacekeeper            [135]
# 137  Peacekeeper            [136]
# 138  Peacekeeper            [137]
# 139  Peacekeeper            [138]
# 140  Peacekeeper            [136]
# 141  Peacekeeper            [140]
# 142  Peacekeeper            [141]
# 143  Peacekeeper            [142]
# 144  Peacekeeper            [143]
# 145  Peacekeeper            [143]
# 146  Peacekeeper            [144]
# 147  Peacekeeper            [146]
# 148  Peacekeeper        [23, 123]
# 149  Peacekeeper   [73, 148, 308]
# 150  Peacekeeper            [108]
# 151  Peacekeeper            [150]
# 152  Peacekeeper            [153]
# 153  Peacekeeper            [127]
# 154  Peacekeeper            [147]
# 155  Peacekeeper            [161]
# 156  Peacekeeper            [139]
# 157  Peacekeeper            [156]
# 158  Peacekeeper            [132]
# 159  Peacekeeper            [130]
# 160  Peacekeeper            [153]
# 161  Peacekeeper            [287]
# 162  Peacekeeper            [153]
# 163  Peacekeeper            [136]
# 164  Peacekeeper       [144, 162]
# 165  Peacekeeper            [156]
# 166     Mechanic               []
# 167     Mechanic            [168]
# 168     Mechanic            [166]
# 169     Mechanic            [168]
# 170     Mechanic            [168]
# 171     Mechanic       [169, 170]
# 172     Mechanic            [171]
# 173     Mechanic            [172]
# 174     Mechanic            [173]
# 175     Mechanic            [174]
# 176     Mechanic            [175]
# 177     Mechanic            [176]
# 178     Mechanic            [177]
# 179     Mechanic            [178]
# 180     Mechanic            [179]
# 181     Mechanic            [180]
# 182     Mechanic            [181]
# 183     Mechanic            [182]
# 184     Mechanic            [183]
# 185     Mechanic            [184]
# 186     Mechanic            [185]
# 187     Mechanic            [186]
# 188     Mechanic            [187]
# 189     Mechanic            [188]
# 190     Mechanic            [189]
# 191     Mechanic            [190]
# 192     Mechanic            [191]
# 193     Mechanic            [169]
# 194     Mechanic       [170, 193]
# 195     Mechanic            [193]
# 196     Mechanic            [195]
# 197     Mechanic            [198]
# 198     Mechanic            [196]
# 199     Mechanic            [195]
# 200     Mechanic            [199]
# 201     Mechanic            [168]
# 202     Mechanic            [201]
# 203     Mechanic            [202]
# 204     Mechanic            [202]
# 205     Mechanic            [204]
# 206     Mechanic            [146]
# 207     Mechanic            [204]
# 208     Mechanic            [205]
# 209     Mechanic            [205]
# 210     Mechanic         [23, 71]
# 211     Mechanic            [210]
# 212     Mechanic            [211]
# 213     Mechanic            [204]
# 214     Mechanic            [205]
# 215     Mechanic            [202]
# 216     Mechanic            [215]
# 217     Mechanic       [213, 216]
# 218     Mechanic            [216]
# 219     Mechanic               []
# 220     Mechanic            [219]
# 221     Mechanic            [220]
# 222     Mechanic            [221]
# 223     Mechanic            [222]
# 224     Mechanic            [223]
# 225     Mechanic            [224]
# 226     Mechanic            [225]
# 227     Mechanic               []
# 228     Mechanic            [227]
# 229     Mechanic            [228]
# 230     Mechanic            [199]
# 231     Mechanic            [200]
# 232     Mechanic            [217]
# 233     Mechanic            [232]
# 234       Ragman               []
# 235       Ragman            [234]
# 236       Ragman            [234]
# 237       Ragman            [239]
# 238       Ragman            [237]
# 239       Ragman       [235, 236]
# 240       Ragman            [239]
# 241       Ragman       [240, 246]
# 242       Ragman            [241]
# 243       Ragman            [242]
# 244       Ragman            [241]
# 245       Ragman       [235, 236]
# 246       Ragman            [245]
# 247       Ragman            [246]
# 248       Ragman            [246]
# 249       Ragman       [239, 248]
# 250       Ragman            [249]
# 251       Ragman            [248]
# 252       Ragman            [251]
# 253       Ragman            [252]
# 254       Ragman       [252, 293]
# 255       Ragman       [244, 252]
# 256       Ragman            [251]
# 257       Ragman       [239, 256]
# 258       Ragman       [250, 257]
# 259       Ragman            [256]
# 260       Ragman       [239, 259]
# 261       Ragman            [259]
# 262       Ragman            [261]
# 263       Ragman            [255]
# 264       Ragman            [263]
# 265       Ragman            [234]
# 266       Ragman            [265]
# 267       Ragman       [247, 266]
# 268       Ragman            [341]
# 269       Ragman            [266]
# 270       Ragman            [236]
# 271       Jaeger            [167]
# 272       Jaeger            [271]
# 273       Jaeger            [272]
# 274       Jaeger            [273]
# 275       Jaeger            [274]
# 276       Jaeger            [275]
# 277       Jaeger            [276]
# 278       Jaeger            [277]
# 279       Jaeger            [275]
# 280       Jaeger            [282]
# 281       Jaeger            [276]
# 282       Jaeger            [281]
# 283       Jaeger            [307]
# 284       Jaeger       [276, 301]
# 285       Jaeger            [321]
# 286       Jaeger               []
# 287       Jaeger            [284]
# 288       Jaeger            [287]
# 289       Jaeger            [287]
# 290       Jaeger            [278]
# 291       Jaeger            [284]
# 292       Jaeger            [284]
# 293       Jaeger       [244, 287]
# 294       Jaeger   [60, 109, 284]
# 295       Jaeger            [294]
# 296       Jaeger       [196, 287]
# 297       Jaeger            [310]
# 298       Jaeger       [284, 297]
# 299       Jaeger            [271]
# 300       Jaeger            [299]
# 301       Jaeger            [300]
# 302       Jaeger            [301]
# 303       Jaeger            [302]
# 304       Jaeger            [303]
# 305       Jaeger            [304]
# 306       Jaeger            [305]
# 307       Jaeger        [91, 271]
# 308       Jaeger   [72, 110, 210]
# 309       Jaeger            [294]
# 310       Jaeger            [286]
# 311       Jaeger        [73, 308]
# 312       Jaeger               []
# 313       Jaeger            [276]
# 314       Jaeger            [287]
# 315       Jaeger  [291, 293, 294]
# 316       Jaeger            [273]
# 317       Jaeger            [316]
# 318       Jaeger       [320, 321]
# 319       Jaeger            [216]
# 320       Jaeger            [319]
# 321       Jaeger            [287]
# 322       Jaeger        [82, 287]
# 323       Jaeger            [320]
# 324        Fence               []
# 325        Fence             [22]
# 326        Fence               []
# 327        Fence               []
# 328        Fence               []
# 329        Fence               []
# 330        Fence               []
# 331  Lightkeeper            [226]
# 332  Lightkeeper            [331]
# 333  Lightkeeper            [332]
# 334  Lightkeeper            [333]
# 335  Lightkeeper            [334]
# 336  Lightkeeper            [335]
# 337  Lightkeeper            [336]
# 338  Lightkeeper            [337]
# 339  Lightkeeper            [338]
# 340  Lightkeeper            [339]
# 341  Lightkeeper            [340]
